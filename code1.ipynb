# %%
import zipfile
import os

def unzip_file(zip_file_path, extract_to):
    # 创建目标目录（如果不存在）
    if not os.path.exists(extract_to):
        os.makedirs(extract_to)

    # 打开ZIP文件并提取所有内容
    with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
        zip_ref.extractall(extract_to)
        print(f"已成功解压到: {extract_to}")

# 示例用法
unzip_file('data.zip', 'DATA')
# Out:
# 已成功解压到: DATA

# %%
import os
from shutil import copy
import random

def create_directory(dir_path):
    """Create a directory if it does not exist."""
    if not os.path.exists(dir_path):
        os.makedirs(dir_path)

# Get the names of all folders in the 'photos' directory, excluding .txt files
file_path = './DATA/data/picture'
flower_classes = [cls for cls in os.listdir(file_path) if os.path.isdir(os.path.join(file_path, cls)) and ".txt" not in cls]

# Create 'train' folder and subdirectories for each of the categories
train_dir = 'picture/train'
create_directory(train_dir)
for cls in flower_classes:
    create_directory(os.path.join(train_dir, cls))

# Create 'val' folder and subdirectories for each of the categories
val_dir = 'picture/val'
create_directory(val_dir)
for cls in flower_classes:
    create_directory(os.path.join(val_dir, cls))

# Split ratio: training set : validation set = 9 : 1
split_rate = 0.1

# Iterate through all images of each category and split them into training and validation sets based on the ratio
for cls in flower_classes:
    cls_path = os.path.join(file_path, cls)  # Subdirectory for a specific category
    images = os.listdir(cls_path)  # List of all image names in the directory
    num_images = len(images)
    
    # Randomly select images for the validation set from the images list
    eval_indices = random.sample(images, k=int(num_images * split_rate))  
    
    for index, image in enumerate(images):
        image_path = os.path.join(cls_path, image)  # Full path of the current image
        
        # Check if the current image is in the validation set list
        if image in eval_indices:
            new_path = os.path.join(val_dir, cls)  # Path for the validation set
        else:
            new_path = os.path.join(train_dir, cls)  # Path for the training set
            
        copy(image_path, new_path)  # Copy the image to the new path
        
        # Display processing progress bar
        print("\r[{}] processing [{}/{}]".format(cls, index + 1, num_images), end="")
    
    print()  # New line

# Now create a separate test set from the validation set (previously called test)
test_dir = 'picture/test'
create_directory(test_dir)
for cls in flower_classes:
    create_directory(os.path.join(test_dir, cls))

# Move a portion of images from val to test
for cls in flower_classes:
    cls_val_path = os.path.join(val_dir, cls)  # Path to validation images for this class
    val_images = os.listdir(cls_val_path)  # List of all validation images for this class
    
    # Randomly select images to move to test from validation set
    test_indices = random.sample(val_images, k=int(len(val_images) * split_rate))
    
    for image in test_indices:
        src_image_path = os.path.join(cls_val_path, image)  # Full path of the image to move to test
        dest_image_path = os.path.join(test_dir, cls, image)  # Destination path for test
        
        copy(src_image_path, dest_image_path)  # Copy image to test directory
        
        print(f"Moved {image} from {cls} validation to test.")

print("Processing done!")  # Processing complete message
# Out:
# [neutral] processing [6198/6198]
# [fear] processing [5121/5121]
# [disgust] processing [547/547]
# [happy] processing [8989/8989]
# [sad] processing [6077/6077]
# [surprise] processing [4002/4002]
# [angry] processing [4953/4953]
# Moved 29438.jpg from neutral validation to test.
# Moved 11354.jpg from neutral validation to test.
# Moved 25817.jpg from neutral validation to test.
# Moved 25052.jpg from neutral validation to test.
# Moved 12650.jpg from neutral validation to test.
# Moved 5945.jpg from neutral validation to test.
# Moved 23538.jpg from neutral validation to test.
# Moved 8763.jpg from neutral validation to test.
# Moved 23729.jpg from neutral validation to test.
# Moved 22075.jpg from neutral validation to test.
# Moved 22688.jpg from neutral validation to test.
# Moved 20618.jpg from neutral validation to test.
# Moved 15571.jpg from neutral validation to test.
# Moved 14983.jpg from neutral validation to test.
# Moved 2092.jpg from neutral validation to test.
# Moved 18422.jpg from neutral validation to test.
# Moved 27163.jpg from neutral validation to test.
# Moved 24091.jpg from neutral validation to test.
# Moved 5536.jpg from neutral validation to test.
# Moved 9292.jpg from neutral validation to test.
# Moved 25030.jpg from neutral validation to test.
# Moved 13771.jpg from neutral validation to test.
# Moved 29268.jpg from neutral validation to test.
# Moved 1347.jpg from neutral validation to test.
# Moved 25660.jpg from neutral validation to test.
# Moved 30614.jpg from neutral validation to test.
# Moved 12731.jpg from neutral validation to test.
# Moved 19324.jpg from neutral validation to test.
# Moved 22974.jpg from neutral validation to test.
# Moved 4599.jpg from neutral validation to test.
# Moved 10045.jpg from neutral validation to test.
# Moved 16453.jpg from neutral validation to test.
# Moved 2493.jpg from neutral validation to test.
# Moved 35450.jpg from neutral validation to test.
# Moved 8193.jpg from neutral validation to test.
# Moved 3290.jpg from neutral validation to test.
# Moved 33018.jpg from neutral validation to test.
# Moved 34563.jpg from neutral validation to test.
# Moved 2440.jpg from neutral validation to test.
# Moved 24575.jpg from neutral validation to test.
# Moved 5980.jpg from neutral validation to test.
# Moved 3006.jpg from neutral validation to test.
# Moved 22882.jpg from neutral validation to test.
# Moved 31576.jpg from neutral validation to test.
# Moved 18579.jpg from neutral validation to test.
# Moved 23643.jpg from neutral validation to test.
# Moved 13821.jpg from neutral validation to test.
# Moved 20008.jpg from neutral validation to test.
# Moved 8567.jpg from neutral validation to test.
# Moved 34321.jpg from neutral validation to test.
# Moved 20357.jpg from neutral validation to test.
# Moved 15591.jpg from neutral validation to test.
# Moved 28846.jpg from neutral validation to test.
# Moved 16845.jpg from neutral validation to test.
# Moved 6630.jpg from neutral validation to test.
# Moved 22707.jpg from neutral validation to test.
# Moved 9484.jpg from neutral validation to test.
# Moved 24972.jpg from neutral validation to test.
# Moved 11097.jpg from neutral validation to test.
# Moved 26172.jpg from neutral validation to test.
# Moved 14852.jpg from neutral validation to test.
# Moved 20524.jpg from neutral validation to test.
# Moved 16824.jpg from neutral validation to test.
# Moved 22414.jpg from neutral validation to test.
# Moved 7968.jpg from neutral validation to test.
# Moved 14009.jpg from neutral validation to test.
# Moved 17163.jpg from neutral validation to test.
# Moved 26495.jpg from neutral validation to test.
# Moved 2369.jpg from neutral validation to test.
# Moved 6018.jpg from neutral validation to test.
# Moved 16524.jpg from neutral validation to test.
# Moved 19890.jpg from neutral validation to test.
# Moved 16194.jpg from neutral validation to test.
# Moved 17154.jpg from neutral validation to test.
# Moved 24443.jpg from neutral validation to test.
# Moved 6805.jpg from neutral validation to test.
# Moved 11123.jpg from neutral validation to test.
# Moved 5015.jpg from neutral validation to test.
# Moved 18024.jpg from neutral validation to test.
# Moved 13992.jpg from neutral validation to test.
# Moved 4822.jpg from neutral validation to test.
# Moved 5849.jpg from neutral validation to test.
# Moved 22447.jpg from neutral validation to test.
# Moved 18586.jpg from neutral validation to test.
# Moved 28484.jpg from neutral validation to test.
# Moved 18909.jpg from neutral validation to test.
# Moved 2562.jpg from neutral validation to test.
# Moved 28507.jpg from neutral validation to test.
# Moved 35441.jpg from neutral validation to test.
# Moved 28025.jpg from neutral validation to test.
# Moved 20115.jpg from neutral validation to test.
# Moved 17266.jpg from neutral validation to test.
# Moved 26536.jpg from neutral validation to test.
# Moved 30379.jpg from neutral validation to test.
# Moved 10200.jpg from neutral validation to test.
# Moved 14867.jpg from neutral validation to test.
# Moved 3072.jpg from neutral validation to test.
# Moved 18240.jpg from neutral validation to test.
# Moved 11542.jpg from neutral validation to test.
# Moved 30954.jpg from neutral validation to test.
# Moved 25391.jpg from neutral validation to test.
# Moved 15826.jpg from neutral validation to test.
# Moved 16464.jpg from neutral validation to test.
# Moved 10068.jpg from neutral validation to test.
# Moved 4836.jpg from neutral validation to test.
# Moved 10381.jpg from neutral validation to test.
# Moved 33462.jpg from neutral validation to test.
# Moved 3055.jpg from neutral validation to test.
# Moved 8546.jpg from neutral validation to test.
# Moved 29921.jpg from neutral validation to test.
# Moved 2580.jpg from neutral validation to test.
# Moved 35070.jpg from neutral validation to test.
# Moved 5589.jpg from neutral validation to test.
# Moved 10062.jpg from neutral validation to test.
# Moved 20948.jpg from neutral validation to test.
# Moved 22224.jpg from neutral validation to test.
# Moved 347.jpg from neutral validation to test.
# Moved 5585.jpg from fear validation to test.
# Moved 7991.jpg from fear validation to test.
# Moved 8796.jpg from fear validation to test.
# Moved 29918.jpg from fear validation to test.
# Moved 21345.jpg from fear validation to test.
# Moved 16270.jpg from fear validation to test.
# Moved 14138.jpg from fear validation to test.
# Moved 11770.jpg from fear validation to test.
# Moved 16440.jpg from fear validation to test.
# Moved 4695.jpg from fear validation to test.
# Moved 34755.jpg from fear validation to test.
# Moved 17817.jpg from fear validation to test.
# Moved 3900.jpg from fear validation to test.
# Moved 6510.jpg from fear validation to test.
# Moved 20668.jpg from fear validation to test.
# Moved 19554.jpg from fear validation to test.
# Moved 3124.jpg from fear validation to test.
# Moved 871.jpg from fear validation to test.
# Moved 11360.jpg from fear validation to test.
# Moved 35413.jpg from fear validation to test.
# Moved 12357.jpg from fear validation to test.
# Moved 14373.jpg from fear validation to test.
# Moved 27817.jpg from fear validation to test.
# Moved 9470.jpg from fear validation to test.
# Moved 907.jpg from fear validation to test.
# Moved 35471.jpg from fear validation to test.
# Moved 23095.jpg from fear validation to test.
# Moved 7819.jpg from fear validation to test.
# Moved 34640.jpg from fear validation to test.
# Moved 23633.jpg from fear validation to test.
# Moved 12572.jpg from fear validation to test.
# Moved 20024.jpg from fear validation to test.
# Moved 27252.jpg from fear validation to test.
# Moved 17792.jpg from fear validation to test.
# Moved 29723.jpg from fear validation to test.
# Moved 15457.jpg from fear validation to test.
# Moved 22875.jpg from fear validation to test.
# Moved 959.jpg from fear validation to test.
# Moved 21244.jpg from fear validation to test.
# Moved 27337.jpg from fear validation to test.
# Moved 11457.jpg from fear validation to test.
# Moved 35541.jpg from fear validation to test.
# Moved 8481.jpg from fear validation to test.
# Moved 2178.jpg from fear validation to test.
# Moved 25482.jpg from fear validation to test.
# Moved 49.jpg from fear validation to test.
# Moved 6163.jpg from fear validation to test.
# Moved 19513.jpg from fear validation to test.
# Moved 19266.jpg from fear validation to test.
# Moved 7327.jpg from fear validation to test.
# Moved 26911.jpg from fear validation to test.
# Moved 27458.jpg from fear validation to test.
# Moved 31568.jpg from fear validation to test.
# Moved 27421.jpg from fear validation to test.
# Moved 21805.jpg from fear validation to test.
# Moved 28113.jpg from fear validation to test.
# Moved 13273.jpg from fear validation to test.
# Moved 23360.jpg from fear validation to test.
# Moved 13301.jpg from fear validation to test.
# Moved 14598.jpg from fear validation to test.
# Moved 2251.jpg from fear validation to test.
# Moved 3966.jpg from fear validation to test.
# Moved 1721.jpg from fear validation to test.
# Moved 23352.jpg from fear validation to test.
# Moved 3824.jpg from fear validation to test.
# Moved 20427.jpg from fear validation to test.
# Moved 32933.jpg from fear validation to test.
# Moved 6071.jpg from fear validation to test.
# Moved 26927.jpg from fear validation to test.
# Moved 11767.jpg from fear validation to test.
# Moved 33264.jpg from fear validation to test.
# Moved 20343.jpg from fear validation to test.
# Moved 12749.jpg from fear validation to test.
# Moved 32504.jpg from fear validation to test.
# Moved 17193.jpg from fear validation to test.
# Moved 17783.jpg from fear validation to test.
# Moved 22743.jpg from fear validation to test.
# Moved 33644.jpg from fear validation to test.
# Moved 301.jpg from fear validation to test.
# Moved 14617.jpg from fear validation to test.
# Moved 32430.jpg from fear validation to test.
# Moved 1240.jpg from fear validation to test.
# Moved 2196.jpg from fear validation to test.
# Moved 11843.jpg from fear validation to test.
# Moved 17859.jpg from fear validation to test.
# Moved 16802.jpg from fear validation to test.
# Moved 4031.jpg from fear validation to test.
# Moved 6144.jpg from fear validation to test.
# Moved 18984.jpg from fear validation to test.
# Moved 35330.jpg from fear validation to test.
# Moved 7816.jpg from fear validation to test.
# Moved 33510.jpg from fear validation to test.
# Moved 20840.jpg from fear validation to test.
# Moved 32201.jpg from fear validation to test.
# Moved 2799.jpg from fear validation to test.
# Moved 9731.jpg from fear validation to test.
# Moved 30247.jpg from fear validation to test.
# Moved 12875.jpg from disgust validation to test.
# Moved 16119.jpg from disgust validation to test.
# Moved 8509.jpg from disgust validation to test.
# Moved 30252.jpg from disgust validation to test.
# Moved 30928.jpg from disgust validation to test.
# Moved 3521.jpg from disgust validation to test.
# Moved 14680.jpg from disgust validation to test.
# Moved 6867.jpg from disgust validation to test.
# Moved 758.jpg from disgust validation to test.
# Moved 1542.jpg from disgust validation to test.
# Moved 28350.jpg from happy validation to test.
# Moved 32257.jpg from happy validation to test.
# Moved 24244.jpg from happy validation to test.
# Moved 2483.jpg from happy validation to test.
# Moved 8488.jpg from happy validation to test.
# Moved 20365.jpg from happy validation to test.
# Moved 33093.jpg from happy validation to test.
# Moved 13754.jpg from happy validation to test.
# Moved 33750.jpg from happy validation to test.
# Moved 19646.jpg from happy validation to test.
# Moved 20777.jpg from happy validation to test.
# Moved 30668.jpg from happy validation to test.
# Moved 6010.jpg from happy validation to test.
# Moved 31410.jpg from happy validation to test.
# Moved 7585.jpg from happy validation to test.
# Moved 15455.jpg from happy validation to test.
# Moved 9935.jpg from happy validation to test.
# Moved 6141.jpg from happy validation to test.
# Moved 7975.jpg from happy validation to test.
# Moved 23282.jpg from happy validation to test.
# Moved 9766.jpg from happy validation to test.
# Moved 4466.jpg from happy validation to test.
# Moved 14994.jpg from happy validation to test.
# Moved 22138.jpg from happy validation to test.
# Moved 24464.jpg from happy validation to test.
# Moved 13885.jpg from happy validation to test.
# Moved 19465.jpg from happy validation to test.
# Moved 18861.jpg from happy validation to test.
# Moved 2678.jpg from happy validation to test.
# Moved 19705.jpg from happy validation to test.
# Moved 34748.jpg from happy validation to test.
# Moved 25118.jpg from happy validation to test.
# Moved 22568.jpg from happy validation to test.
# Moved 12857.jpg from happy validation to test.
# Moved 30542.jpg from happy validation to test.
# Moved 24445.jpg from happy validation to test.
# Moved 3287.jpg from happy validation to test.
# Moved 22710.jpg from happy validation to test.
# Moved 25086.jpg from happy validation to test.
# Moved 19783.jpg from happy validation to test.
# Moved 17965.jpg from happy validation to test.
# Moved 13884.jpg from happy validation to test.
# Moved 14700.jpg from happy validation to test.
# Moved 13229.jpg from happy validation to test.
# Moved 11649.jpg from happy validation to test.
# Moved 3405.jpg from happy validation to test.
# Moved 9248.jpg from happy validation to test.
# Moved 7850.jpg from happy validation to test.
# Moved 29842.jpg from happy validation to test.
# Moved 1056.jpg from happy validation to test.
# Moved 5288.jpg from happy validation to test.
# Moved 13872.jpg from happy validation to test.
# Moved 5913.jpg from happy validation to test.
# Moved 10691.jpg from happy validation to test.
# Moved 35381.jpg from happy validation to test.
# Moved 216.jpg from happy validation to test.
# Moved 27605.jpg from happy validation to test.
# Moved 34888.jpg from happy validation to test.
# Moved 19033.jpg from happy validation to test.
# Moved 20735.jpg from happy validation to test.
# Moved 35769.jpg from happy validation to test.
# Moved 28770.jpg from happy validation to test.
# Moved 8945.jpg from happy validation to test.
# Moved 10641.jpg from happy validation to test.
# Moved 33727.jpg from happy validation to test.
# Moved 28890.jpg from happy validation to test.
# Moved 8065.jpg from happy validation to test.
# Moved 14625.jpg from happy validation to test.
# Moved 30276.jpg from happy validation to test.
# Moved 33480.jpg from happy validation to test.
# Moved 35721.jpg from happy validation to test.
# Moved 30730.jpg from happy validation to test.
# Moved 23120.jpg from happy validation to test.
# Moved 19918.jpg from happy validation to test.
# Moved 19019.jpg from happy validation to test.
# Moved 13848.jpg from happy validation to test.
# Moved 20049.jpg from happy validation to test.
# Moved 25873.jpg from happy validation to test.
# Moved 18126.jpg from happy validation to test.
# Moved 14952.jpg from happy validation to test.
# Moved 8030.jpg from happy validation to test.
# Moved 11392.jpg from happy validation to test.
# Moved 27060.jpg from happy validation to test.
# Moved 22470.jpg from happy validation to test.
# Moved 21529.jpg from happy validation to test.
# Moved 5498.jpg from happy validation to test.
# Moved 21341.jpg from happy validation to test.
# Moved 19040.jpg from happy validation to test.
# Moved 22500.jpg from happy validation to test.
# Moved 5373.jpg from happy validation to test.
# Moved 27504.jpg from happy validation to test.
# Moved 29800.jpg from happy validation to test.
# Moved 17803.jpg from happy validation to test.
# Moved 35139.jpg from happy validation to test.
# Moved 19947.jpg from happy validation to test.
# Moved 25332.jpg from happy validation to test.
# Moved 29831.jpg from happy validation to test.
# Moved 34245.jpg from happy validation to test.
# Moved 17491.jpg from happy validation to test.
# Moved 10974.jpg from happy validation to test.
# Moved 34265.jpg from happy validation to test.
# Moved 8322.jpg from happy validation to test.
# Moved 33099.jpg from happy validation to test.
# Moved 8539.jpg from happy validation to test.
# Moved 3131.jpg from happy validation to test.
# Moved 34783.jpg from happy validation to test.
# Moved 6885.jpg from happy validation to test.
# Moved 5464.jpg from happy validation to test.
# Moved 34391.jpg from happy validation to test.
# Moved 29967.jpg from happy validation to test.
# Moved 33895.jpg from happy validation to test.
# Moved 30855.jpg from happy validation to test.
# Moved 23776.jpg from happy validation to test.
# Moved 17609.jpg from happy validation to test.
# Moved 14345.jpg from happy validation to test.
# Moved 19620.jpg from happy validation to test.
# Moved 20861.jpg from happy validation to test.
# Moved 1963.jpg from happy validation to test.
# Moved 17997.jpg from happy validation to test.
# Moved 24747.jpg from happy validation to test.
# Moved 34361.jpg from happy validation to test.
# Moved 32944.jpg from happy validation to test.
# Moved 8704.jpg from happy validation to test.
# Moved 7598.jpg from happy validation to test.
# Moved 17141.jpg from happy validation to test.
# Moved 12306.jpg from happy validation to test.
# Moved 18867.jpg from happy validation to test.
# Moved 19250.jpg from happy validation to test.
# Moved 20780.jpg from happy validation to test.
# Moved 15247.jpg from happy validation to test.
# Moved 22686.jpg from happy validation to test.
# Moved 25096.jpg from happy validation to test.
# Moved 32629.jpg from happy validation to test.
# Moved 19139.jpg from happy validation to test.
# Moved 16007.jpg from happy validation to test.
# Moved 31017.jpg from happy validation to test.
# Moved 33551.jpg from happy validation to test.
# Moved 26459.jpg from happy validation to test.
# Moved 19971.jpg from happy validation to test.
# Moved 14903.jpg from happy validation to test.
# Moved 12415.jpg from happy validation to test.
# Moved 16342.jpg from happy validation to test.
# Moved 33862.jpg from happy validation to test.
# Moved 3959.jpg from happy validation to test.
# Moved 11236.jpg from happy validation to test.
# Moved 12779.jpg from happy validation to test.
# Moved 25747.jpg from happy validation to test.
# Moved 26737.jpg from happy validation to test.
# Moved 9257.jpg from happy validation to test.
# Moved 14991.jpg from happy validation to test.
# Moved 1746.jpg from happy validation to test.
# Moved 809.jpg from happy validation to test.
# Moved 33065.jpg from happy validation to test.
# Moved 19449.jpg from happy validation to test.
# Moved 2745.jpg from happy validation to test.
# Moved 25328.jpg from happy validation to test.
# Moved 32457.jpg from happy validation to test.
# Moved 19308.jpg from happy validation to test.
# Moved 144.jpg from happy validation to test.
# Moved 22569.jpg from happy validation to test.
# Moved 16495.jpg from happy validation to test.
# Moved 13005.jpg from happy validation to test.
# Moved 3410.jpg from happy validation to test.
# Moved 19002.jpg from happy validation to test.
# Moved 14973.jpg from happy validation to test.
# Moved 21218.jpg from happy validation to test.
# Moved 31551.jpg from happy validation to test.
# Moved 17928.jpg from happy validation to test.
# Moved 8766.jpg from happy validation to test.
# Moved 14587.jpg from happy validation to test.
# Moved 1488.jpg from happy validation to test.
# Moved 3118.jpg from sad validation to test.
# Moved 14769.jpg from sad validation to test.
# Moved 26580.jpg from sad validation to test.
# Moved 13484.jpg from sad validation to test.
# Moved 8044.jpg from sad validation to test.
# Moved 12336.jpg from sad validation to test.
# Moved 32731.jpg from sad validation to test.
# Moved 21847.jpg from sad validation to test.
# Moved 16485.jpg from sad validation to test.
# Moved 910.jpg from sad validation to test.
# Moved 24693.jpg from sad validation to test.
# Moved 17889.jpg from sad validation to test.
# Moved 28615.jpg from sad validation to test.
# Moved 1612.jpg from sad validation to test.
# Moved 13065.jpg from sad validation to test.
# Moved 5125.jpg from sad validation to test.
# Moved 30323.jpg from sad validation to test.
# Moved 25369.jpg from sad validation to test.
# Moved 28665.jpg from sad validation to test.
# Moved 16602.jpg from sad validation to test.
# Moved 35549.jpg from sad validation to test.
# Moved 10531.jpg from sad validation to test.
# Moved 27873.jpg from sad validation to test.
# Moved 21435.jpg from sad validation to test.
# Moved 8469.jpg from sad validation to test.
# Moved 14879.jpg from sad validation to test.
# Moved 7546.jpg from sad validation to test.
# Moved 6992.jpg from sad validation to test.
# Moved 20494.jpg from sad validation to test.
# Moved 6886.jpg from sad validation to test.
# Moved 31220.jpg from sad validation to test.
# Moved 13243.jpg from sad validation to test.
# Moved 15177.jpg from sad validation to test.
# Moved 8851.jpg from sad validation to test.
# Moved 25734.jpg from sad validation to test.
# Moved 18124.jpg from sad validation to test.
# Moved 2815.jpg from sad validation to test.
# Moved 17642.jpg from sad validation to test.
# Moved 17257.jpg from sad validation to test.
# Moved 21667.jpg from sad validation to test.
# Moved 10859.jpg from sad validation to test.
# Moved 19116.jpg from sad validation to test.
# Moved 7647.jpg from sad validation to test.
# Moved 8197.jpg from sad validation to test.
# Moved 32966.jpg from sad validation to test.
# Moved 11657.jpg from sad validation to test.
# Moved 29489.jpg from sad validation to test.
# Moved 22014.jpg from sad validation to test.
# Moved 29231.jpg from sad validation to test.
# Moved 9327.jpg from sad validation to test.
# Moved 18085.jpg from sad validation to test.
# Moved 19731.jpg from sad validation to test.
# Moved 776.jpg from sad validation to test.
# Moved 1293.jpg from sad validation to test.
# Moved 7252.jpg from sad validation to test.
# Moved 21815.jpg from sad validation to test.
# Moved 752.jpg from sad validation to test.
# Moved 14273.jpg from sad validation to test.
# Moved 21678.jpg from sad validation to test.
# Moved 35393.jpg from sad validation to test.
# Moved 28374.jpg from sad validation to test.
# Moved 5029.jpg from sad validation to test.
# Moved 34873.jpg from sad validation to test.
# Moved 27849.jpg from sad validation to test.
# Moved 33614.jpg from sad validation to test.
# Moved 20313.jpg from sad validation to test.
# Moved 24940.jpg from sad validation to test.
# Moved 31656.jpg from sad validation to test.
# Moved 30104.jpg from sad validation to test.
# Moved 17412.jpg from sad validation to test.
# Moved 22728.jpg from sad validation to test.
# Moved 16852.jpg from sad validation to test.
# Moved 4023.jpg from sad validation to test.
# Moved 19385.jpg from sad validation to test.
# Moved 32268.jpg from sad validation to test.
# Moved 25557.jpg from sad validation to test.
# Moved 10737.jpg from sad validation to test.
# Moved 14465.jpg from sad validation to test.
# Moved 32446.jpg from sad validation to test.
# Moved 559.jpg from sad validation to test.
# Moved 23180.jpg from sad validation to test.
# Moved 9008.jpg from sad validation to test.
# Moved 18550.jpg from sad validation to test.
# Moved 12658.jpg from sad validation to test.
# Moved 30032.jpg from sad validation to test.
# Moved 26305.jpg from sad validation to test.
# Moved 27786.jpg from sad validation to test.
# Moved 9102.jpg from sad validation to test.
# Moved 30144.jpg from sad validation to test.
# Moved 359.jpg from sad validation to test.
# Moved 25588.jpg from sad validation to test.
# Moved 13052.jpg from sad validation to test.
# Moved 11021.jpg from sad validation to test.
# Moved 23781.jpg from sad validation to test.
# Moved 24916.jpg from sad validation to test.
# Moved 30442.jpg from sad validation to test.
# Moved 18732.jpg from sad validation to test.
# Moved 13098.jpg from sad validation to test.
# Moved 21786.jpg from sad validation to test.
# Moved 18350.jpg from sad validation to test.
# Moved 16003.jpg from sad validation to test.
# Moved 22816.jpg from sad validation to test.
# Moved 7453.jpg from sad validation to test.
# Moved 34633.jpg from sad validation to test.
# Moved 4864.jpg from sad validation to test.
# Moved 26030.jpg from sad validation to test.
# Moved 15732.jpg from sad validation to test.
# Moved 3256.jpg from sad validation to test.
# Moved 8942.jpg from sad validation to test.
# Moved 9283.jpg from sad validation to test.
# Moved 23105.jpg from sad validation to test.
# Moved 32234.jpg from sad validation to test.
# Moved 35271.jpg from sad validation to test.
# Moved 26991.jpg from sad validation to test.
# Moved 5040.jpg from surprise validation to test.
# Moved 18273.jpg from surprise validation to test.
# Moved 5513.jpg from surprise validation to test.
# Moved 21366.jpg from surprise validation to test.
# Moved 30597.jpg from surprise validation to test.
# Moved 12080.jpg from surprise validation to test.
# Moved 9164.jpg from surprise validation to test.
# Moved 51.jpg from surprise validation to test.
# Moved 14205.jpg from surprise validation to test.
# Moved 15.jpg from surprise validation to test.
# Moved 20712.jpg from surprise validation to test.
# Moved 1318.jpg from surprise validation to test.
# Moved 19039.jpg from surprise validation to test.
# Moved 7512.jpg from surprise validation to test.
# Moved 12385.jpg from surprise validation to test.
# Moved 30590.jpg from surprise validation to test.
# Moved 15241.jpg from surprise validation to test.
# Moved 8206.jpg from surprise validation to test.
# Moved 35875.jpg from surprise validation to test.
# Moved 7419.jpg from surprise validation to test.
# Moved 34757.jpg from surprise validation to test.
# Moved 27034.jpg from surprise validation to test.
# Moved 24921.jpg from surprise validation to test.
# Moved 15766.jpg from surprise validation to test.
# Moved 22583.jpg from surprise validation to test.
# Moved 24599.jpg from surprise validation to test.
# Moved 29568.jpg from surprise validation to test.
# Moved 11911.jpg from surprise validation to test.
# Moved 19351.jpg from surprise validation to test.
# Moved 6439.jpg from surprise validation to test.
# Moved 13667.jpg from surprise validation to test.
# Moved 16145.jpg from surprise validation to test.
# Moved 28793.jpg from surprise validation to test.
# Moved 23254.jpg from surprise validation to test.
# Moved 2466.jpg from surprise validation to test.
# Moved 13379.jpg from surprise validation to test.
# Moved 30423.jpg from surprise validation to test.
# Moved 23011.jpg from surprise validation to test.
# Moved 26074.jpg from surprise validation to test.
# Moved 10374.jpg from surprise validation to test.
# Moved 35586.jpg from surprise validation to test.
# Moved 18982.jpg from surprise validation to test.
# Moved 16888.jpg from surprise validation to test.
# Moved 6441.jpg from surprise validation to test.
# Moved 35790.jpg from surprise validation to test.
# Moved 31741.jpg from surprise validation to test.
# Moved 13713.jpg from surprise validation to test.
# Moved 11339.jpg from surprise validation to test.
# Moved 32660.jpg from surprise validation to test.
# Moved 8140.jpg from surprise validation to test.
# Moved 31664.jpg from surprise validation to test.
# Moved 3627.jpg from surprise validation to test.
# Moved 12178.jpg from surprise validation to test.
# Moved 33272.jpg from surprise validation to test.
# Moved 9109.jpg from surprise validation to test.
# Moved 15263.jpg from surprise validation to test.
# Moved 11589.jpg from surprise validation to test.
# Moved 29196.jpg from surprise validation to test.
# Moved 3291.jpg from surprise validation to test.
# Moved 19267.jpg from surprise validation to test.
# Moved 6411.jpg from surprise validation to test.
# Moved 23330.jpg from surprise validation to test.
# Moved 9199.jpg from surprise validation to test.
# Moved 17540.jpg from surprise validation to test.
# Moved 16713.jpg from surprise validation to test.
# Moved 15245.jpg from surprise validation to test.
# Moved 20584.jpg from surprise validation to test.
# Moved 17593.jpg from surprise validation to test.
# Moved 15937.jpg from surprise validation to test.
# Moved 18172.jpg from surprise validation to test.
# Moved 4536.jpg from surprise validation to test.
# Moved 26003.jpg from surprise validation to test.
# Moved 28902.jpg from surprise validation to test.
# Moved 29466.jpg from surprise validation to test.
# Moved 23128.jpg from surprise validation to test.
# Moved 4585.jpg from angry validation to test.
# Moved 19737.jpg from angry validation to test.
# Moved 30890.jpg from angry validation to test.
# Moved 19631.jpg from angry validation to test.
# Moved 241.jpg from angry validation to test.
# Moved 19502.jpg from angry validation to test.
# Moved 13640.jpg from angry validation to test.
# Moved 404.jpg from angry validation to test.
# Moved 1.jpg from angry validation to test.
# Moved 32992.jpg from angry validation to test.
# Moved 32600.jpg from angry validation to test.
# Moved 28614.jpg from angry validation to test.
# Moved 9468.jpg from angry validation to test.
# Moved 8051.jpg from angry validation to test.
# Moved 2826.jpg from angry validation to test.
# Moved 25060.jpg from angry validation to test.
# Moved 26446.jpg from angry validation to test.
# Moved 20871.jpg from angry validation to test.
# Moved 26193.jpg from angry validation to test.
# Moved 17752.jpg from angry validation to test.
# Moved 17981.jpg from angry validation to test.
# Moved 91.jpg from angry validation to test.
# Moved 33114.jpg from angry validation to test.
# Moved 851.jpg from angry validation to test.
# Moved 1252.jpg from angry validation to test.
# Moved 30309.jpg from angry validation to test.
# Moved 7545.jpg from angry validation to test.
# Moved 12025.jpg from angry validation to test.
# Moved 33162.jpg from angry validation to test.
# Moved 19491.jpg from angry validation to test.
# Moved 12392.jpg from angry validation to test.
# Moved 9249.jpg from angry validation to test.
# Moved 1957.jpg from angry validation to test.
# Moved 15273.jpg from angry validation to test.
# Moved 5434.jpg from angry validation to test.
# Moved 3956.jpg from angry validation to test.
# Moved 33772.jpg from angry validation to test.
# Moved 4459.jpg from angry validation to test.
# Moved 11887.jpg from angry validation to test.
# Moved 1899.jpg from angry validation to test.
# Moved 4847.jpg from angry validation to test.
# Moved 28830.jpg from angry validation to test.
# Moved 15562.jpg from angry validation to test.
# Moved 1595.jpg from angry validation to test.
# Moved 32433.jpg from angry validation to test.
# Moved 22183.jpg from angry validation to test.
# Moved 28526.jpg from angry validation to test.
# Moved 2193.jpg from angry validation to test.
# Moved 12198.jpg from angry validation to test.
# Moved 27674.jpg from angry validation to test.
# Moved 8721.jpg from angry validation to test.
# Moved 25489.jpg from angry validation to test.
# Moved 10373.jpg from angry validation to test.
# Moved 8684.jpg from angry validation to test.
# Moved 10038.jpg from angry validation to test.
# Moved 22291.jpg from angry validation to test.
# Moved 1358.jpg from angry validation to test.
# Moved 28974.jpg from angry validation to test.
# Moved 3905.jpg from angry validation to test.
# Moved 12124.jpg from angry validation to test.
# Moved 22175.jpg from angry validation to test.
# Moved 26595.jpg from angry validation to test.
# Moved 4543.jpg from angry validation to test.
# Moved 19835.jpg from angry validation to test.
# Moved 3053.jpg from angry validation to test.
# Moved 6944.jpg from angry validation to test.
# Moved 21673.jpg from angry validation to test.
# Moved 169.jpg from angry validation to test.
# Moved 28709.jpg from angry validation to test.
# Moved 35808.jpg from angry validation to test.
# Moved 5902.jpg from angry validation to test.
# Moved 20110.jpg from angry validation to test.
# Moved 12616.jpg from angry validation to test.
# Moved 13451.jpg from angry validation to test.
# Moved 35190.jpg from angry validation to test.
# Moved 35572.jpg from angry validation to test.
# Moved 20582.jpg from angry validation to test.
# Moved 19394.jpg from angry validation to test.
# Moved 14768.jpg from angry validation to test.
# Moved 17536.jpg from angry validation to test.
# Moved 35681.jpg from angry validation to test.
# Moved 8431.jpg from angry validation to test.
# Moved 17448.jpg from angry validation to test.
# Moved 11949.jpg from angry validation to test.
# Moved 14217.jpg from angry validation to test.
# Moved 3787.jpg from angry validation to test.
# Moved 22625.jpg from angry validation to test.
# Moved 1108.jpg from angry validation to test.
# Moved 16312.jpg from angry validation to test.
# Moved 932.jpg from angry validation to test.
# Moved 16764.jpg from angry validation to test.
# Moved 22877.jpg from angry validation to test.
# Moved 24839.jpg from angry validation to test.
# Processing done!
